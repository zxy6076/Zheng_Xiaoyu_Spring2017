# %% [markdown]
# # Question2_1
#
# 1. using NYT archive API in 1990_06
# 2. finding section_name of articel in 1990_06
# 3. calculating frequency of each section_name and getting top 20
# 4. generating a .csv to show the result

# %%
import glob
import os
import json
from pathlib import Path
from collections import Counter
import csv

# %%
p = Path(os.getcwd())
archive_path = str(p.parent)+ r'\data\download\archive\1990_06\*'

# %%
# to get the section_name and put them into the section_name_list

files = glob.glob(archive_path)
section_name_list = []

for file in files:
    with open(file, 'r') as F:
        python_data = json.load(F)
        doc_elements = python_data['response']['docs']
        for docs in doc_elements:
            if 'section_name' in docs:
                section_name = docs['section_name']
                section_name_list.append(section_name)

#print(len(section_name_list))    ------  72479

# %%
#calculating frequency of each section_name and getting top 10
section_name_counter = Counter()
for name in section_name_list:
    section_name_counter.update([name])
# print(len(section_name_counter)) ----- 150
for name,fre in section_name_counter.most_common(150):
    print(name,'---',fre)
# Out:
# 150
# Business --- 10615
# New York and Region --- 7359
# Sports --- 7150
# Style --- 5973
# Opinion --- 4961
# U.S. --- 4906
# Arts --- 4763
# World --- 4092
# Obituaries --- 2783
# Arts; Books --- 1694
# World; Washington --- 1408
# Corrections; New York and Region --- 1199
# None --- 1012
# Real Estate --- 737
# Home and Garden; Style --- 715
# Education; New York and Region --- 671
# Technology; Business --- 671
# Arts; Theater --- 616
# Travel --- 583
# Week in Review --- 583
# Movies; Arts --- 561
# Sports; Opinion --- 462
# Front Page; U.S. --- 451
# Home and Garden --- 451
# World; Front Page --- 440
# Front Page; New York and Region --- 418
# Health; U.S. --- 396
# Science; Health --- 385
# New York and Region; Opinion --- 319
# Arts; Books; Opinion --- 319
# Magazine --- 308
# Magazine; Opinion --- 286
# U.S.; Washington --- 242
# Health; New York and Region --- 220
# Theater; New York and Region --- 220
# Front Page; Business --- 198
# World; Front Page; Washington --- 176
# Technology; Science; Health --- 165
# Arts; Opinion --- 154
# Health; Business --- 154
# Health; Style --- 154
# Home and Garden; Style; Magazine --- 154
# Front Page --- 143
# World; Business; Magazine --- 132
# Education; U.S. --- 132
# Travel; New York and Region --- 132
# Business; Opinion --- 121
# Business; Books --- 121
# Health; Sports --- 110
# Corrections --- 99
# Washington; New York and Region --- 88
# Education; Magazine; Opinion --- 88
# World; Education --- 77
# Real Estate; Opinion --- 77
# Front Page; Education; U.S. --- 66
# World; Health --- 66
# Movies; Arts; Opinion --- 55
# Education; Style --- 55
# Home and Garden; Opinion --- 55
# Health; Opinion --- 55
# Movies; Style --- 44
# Corrections; Opinion --- 44
# Front Page; Education; New York and Region --- 44
# Movies; Business --- 44
# Corrections; Editors' Notes; New York and Region --- 44
# Style; Books --- 44
# Style; Theater --- 44
# Front Page; U.S.; Washington --- 44
# Corrections; Washington; New York and Region --- 33
# Washington; Week in Review --- 33
# Style; Washington --- 33
# Education; New York and Region; Opinion --- 33
# Health; Magazine --- 33
# Technology; Front Page; Business --- 33
# Education; Business --- 33
# Sports; Books --- 33
# Travel; Style --- 22
# Books; New York and Region --- 22
# Corrections; Business --- 22
# Technology; Science; World --- 22
# Magazine; Washington; Opinion --- 22
# Home and Garden; Health --- 22
# Education; Magazine --- 22
# Education; Corrections; New York and Region --- 22
# Home and Garden; Style; Opinion --- 22
# Theater; Week in Review --- 22
# Theater; Corrections; New York and Region --- 22
# Corrections; Real Estate --- 22
# Technology; New York and Region --- 22
# Corrections; Sports --- 22
# Magazine; Books --- 22
# Science; U.S. --- 22
# Front Page; Sports --- 22
# Technology; Week in Review --- 22
# Home and Garden; Education; Style --- 22
# Education; Week in Review --- 22
# U.S.; Books --- 22
# Arts; Theater; Opinion --- 22
# Front Page; Arts --- 22
# Technology; Science; U.S. --- 11
# Movies; Obituaries --- 11
# Travel; Business --- 11
# Technology; Corrections; New York and Region --- 11
# Technology; Science; Style --- 11
# Movies; Theater; Obituaries --- 11
# World; Education; Washington --- 11
# Travel; Arts; Books --- 11
# Technology; Health; U.S. --- 11
# Style; Corrections --- 11
# Business; Washington --- 11
# Front Page; Corrections; Washington; New York and Region --- 11
# Technology; Front Page; New York and Region --- 11
# Washington --- 11
# Arts; Corrections --- 11
# Education --- 11
# Science; World; Front Page --- 11
# Corrections; Week in Review --- 11
# Technology; Science; Front Page; U.S. --- 11
# Obituaries; Books --- 11
# Technology; Front Page; Health; Business --- 11
# Science; Front Page; Health; Books --- 11
# Home and Garden; Travel --- 11
# Front Page; Business; Washington --- 11
# Arts; Theater; Corrections --- 11
# Movies; Front Page; Business --- 11
# World; Education; Business; Magazine --- 11
# Magazine; Washington --- 11
# Movies; New York and Region --- 11
# Arts; Corrections; Books --- 11
# Front Page; Health; U.S. --- 11
# World; Books --- 11
# Technology; Health; Business --- 11
# Education; U.S.; Washington --- 11
# Technology; U.S. --- 11
# Science; Technology; Business --- 11
# Magazine; Washington; Books --- 11
# Books; Opinion --- 11
# Education; Real Estate --- 11
# Technology; Business; Opinion --- 11
# Education; Corrections; Editors' Notes; New York and Region --- 11
# Technology; Education; New York and Region --- 11
# Arts; Education; Opinion --- 11
# Front Page; Health; Washington; New York and Region --- 11
# Travel; Theater --- 11
# Home and Garden; Travel; Style --- 11
# Travel; Arts --- 11
# Science; Front Page --- 11
# Arts; Health --- 11
# Technology; Front Page; Obituaries --- 11
# Movies; Style; Theater --- 11

# %%
#generating a .csv to show the result
output_path = str(p.parent)+ r'\que2\ana_1\archive_section_name_1990_06.csv'

with open(output_path,'w') as OF:
    writer = csv.DictWriter(OF,fieldnames=['Section_Name','Frequency'])
    writer.writeheader()
    for name , fre in section_name_counter.most_common(20):
        writer.writerow({'Section_Name':name,'Frequency':fre })
